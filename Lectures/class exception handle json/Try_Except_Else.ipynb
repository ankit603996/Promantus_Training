# %%
a = 5
print(b*5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b0f9a5cc2a19> in <module>()
#       1 a = 5
# ----> 2 print(b*5)
#
# NameError: name 'b' is not defined

# %%
a = 5
b =3

# %%
try:
    c= (a*b)
except(NameError):
    print("!!check if you have defined the variable")
else:
    print("value of sum: ", c)
# Out:
# value of sum:  15

# %%
wz = 10
y = 1


try:
    c= (wz/y)
except(NameError):
    print("!!check if you have defined the variable")
except(ZeroDivisionError):
    print("Please check the denominator")
else:
    print("value of sum: ", c)
# Out:
# value of sum:  10.0

# %%
x = 10
y = 0
try:
    c= (x/z)
except(NameError):
    print("!!check if you have defined the variable")
except(ZeroDivisionError):
    print("Please check the denominator")
else:
    print("value of sum: ", c)
# Out:
# !!check if you have defined the variable
