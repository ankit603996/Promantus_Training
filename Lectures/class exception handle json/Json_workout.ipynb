# %%
import json

# %% [markdown]
# ## Convert json to Python dict

# %%
# some JSON:
x =  '{ "Company":"Promanthus", "address":"Chennai", "State":"Tamil Nade", "Country":"India", "Continent":"Asia"}'

# %%
type(x)
# Out:
# str

# %%
y = json.loads(x)

# %%
type(y)
# Out:
# dict

# %%
y
# Out:
# {'Company': 'Promanthus',
#  'Continent': 'Asia',
#  'Country': 'India',
#  'State': 'Tamil Nade',
#  'address': 'Chennai'}

# %%
y['Company']
# Out:
# 'Promanthus'

# %% [markdown]
# ## Lets try some list with the json

# %%
# some JSON:
x =  '{ "Company":"Promanthus", "address":["Chennai", "Bangalore", "US"], "State":"Tamil Nadu", "Country":"India", "Continent":"Asia"}'

# %%
y = json.loads(x)
type(y)
# Out:
# dict

# %%
y['address']
# Out:
# ['Chennai', 'Bangalore', 'US']

# %%
for i in y['address']:
  print(i)
# Out:
# Chennai
# Bangalore
# US

# %% [markdown]
# ## Convert Python objects to Json

# %%
## Convert Python objects to Json

# %%
x_st = json.dumps(y)

# %%
type(x_st)
# Out:
# str

# %%
print(x_st)
# Out:
# {"Company": "Promanthus", "address": ["Chennai", "Bangalore", "US"], "State": "Tamil Nadu", "Country": "India", "Continent": "Asia"}

# %% [markdown]
# ##Convert some advanced dict to json

# %%
x = {
  "Company": "Promanthus",
  "Yea_Exp": 6,
  "Dev Services": True,
  "Cloud Services": True,
  "Locations": ("Bangalore","India"),
  "Employee_details": [
    {"name": "emp1", "exp": 5},
    {"name": "emp2", "exp": 3.5}
  ]
}

print(json.dumps(x))
# Out:
# {"Company": "Promanthus", "Yea_Exp": 6, "Dev Services": true, "Cloud Services": true, "Locations": ["Bangalore", "India"], "Employee_details": [{"name": "emp1", "exp": 5}, {"name": "emp2", "exp": 3.5}]}

# %%
x
# Out:
# {'Cloud Services': True,
#  'Company': 'Promanthus',
#  'Dev Services': True,
#  'Employee_details': [{'exp': 5, 'name': 'emp1'},
#   {'exp': 3.5, 'name': 'emp2'}],
#  'Locations': ('Bangalore', 'India'),
#  'Yea_Exp': 6}

# %%
print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %%
print(type(json.dumps({"name": "John", "age": 30})))
print(type(json.dumps(["apple", "bananas"])))
print(type(json.dumps(("apple", "bananas"))))
print(type(json.dumps("hello")))
print(type(json.dumps(42)))
print(type(json.dumps(31.76)))
print(type(json.dumps(True)))
print(type(json.dumps(False)))
print(type(json.dumps(None)))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
